# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler


data = pd.read_csv('data_preprocessing.csv')


imputer = SimpleImputer(strategy='mean')
data[['Age', 'Salary']] = imputer.fit_transform(data[['Age', 'Salary']])


label_encoder_country = LabelEncoder()
data['Country'] = label_encoder_country.fit_transform(data['Country'])

label_encoder_purchase = LabelEncoder()
data['Purchased'] = label_encoder_purchase.fit_transform(data['Purchased'])


scaler = StandardScaler()
data[['Age', 'Salary']] = scaler.fit_transform(data[['Age', 'Salary']])


print(data)
# Out:
#    Country       Age        Salary  Purchased
# 0        0  0.758874  7.494733e-01          0
# 1        2 -1.711504 -1.438178e+00          1
# 2        1 -1.275555 -8.912655e-01          0
# 3        2 -0.113024 -2.532004e-01          0
# 4        1  0.177609  6.632192e-16          1
# 5        0 -0.548973 -5.266569e-01          1
# 6        2  0.000000 -1.073570e+00          0
# 7        0  1.340140  1.387538e+00          1
# 8        1  1.630773  1.752147e+00          0
# 9        0 -0.258340  2.937125e-01          1
