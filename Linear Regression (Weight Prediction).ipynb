# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


height = np.array([151, 174, 138, 186, 128, 136, 179, 163, 152]).reshape(-1, 1)
weight = np.array([63, 81, 56, 91, 47, 57, 76, 72, 62])


model = LinearRegression()
model.fit(height, weight)


predicted_weight = model.predict(height)


print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
print("Equation: weight = {:.2f} * height + {:.2f}".format(model.coef_[0], model.intercept_))
plt.scatter(height, weight, color='blue', label='Actual')
plt.plot(height, predicted_weight, color='red', label='Predicted Line')
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
plt.title("Linear Regression: Height vs Weight")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Slope: 0.6600995024875621
# Intercept: -35.973333333333315
# Equation: weight = 0.66 * height + -35.97
